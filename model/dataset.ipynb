# %%
import pandas as pd

# %%
movies = pd.read_csv('datasets/movies.csv')
credits = pd.read_csv('datasets/credits.csv')

# %%
# Merging movies and credits datasets using 'title' as common column
movies = movies.merge(credits, on='title')

# %%
# Choosing specific columns for content filtering based recommendation
movies = movies[['id', 'title', 'overview', 'genres',
                 'keywords', 'popularity', 'cast', 'crew', 
                 'production_companies', 'runtime', 'release_date']]

# %%
# Remove missing(NaN) rows
movies.dropna(inplace=True)

# Duplicated values check
movies.duplicated().sum()

# Remove duplicated rows
movies.drop_duplicates(inplace=True)

# %%
import ast

# Extraction function
def extract_names(obj):
    extracted_names = [i['name'] for i in ast.literal_eval(obj)]
    return ', '.join(extracted_names)

# %%
# Apply the extraction function to the 'genres' column
movies['genres'] = movies['genres'].apply(extract_names)

# Display the result
print(movies['genres'].iloc[0])
# Out:
# Action, Adventure, Fantasy, Science Fiction

# %%
# Apply the extraction function to the 'keywords' column
movies['keywords'] = movies['keywords'].apply(extract_names)

# Display the result
movies['keywords']
# Out:
# 0       culture clash, future, space war, space colony...
# 1       ocean, drug abuse, exotic island, east india t...
# 2       spy, based on novel, secret agent, sequel, mi6...
# 3       dc comics, crime fighter, terrorist, secret id...
# 4       based on novel, mars, medallion, space travel,...
#                               ...
# 4804    united states–mexico barrier, legs, arms, pape...
# 4805
# 4806    date, love at first sight, narration, investig...
# 4807
# 4808              obsession, camcorder, crush, dream girl
# Name: keywords, Length: 4805, dtype: object

# %%
# Extraction function with a limit of 5 names
def extract_cast_with_characters(obj, limit=5):
    cast_list = ast.literal_eval(obj)
    result_str = ', '.join([f"{i['name']} ({i['character']})" for i in cast_list[:limit]])
    return result_str

# %%
movies['cast'] = movies['cast'].apply(extract_cast_with_characters)

print(movies['cast'].iloc[0])
# Out:
# Sam Worthington (Jake Sully), Zoe Saldana (Neytiri), Sigourney Weaver (Dr. Grace Augustine), Stephen Lang (Col. Quaritch), Michelle Rodriguez (Trudy Chacon)

# %%
# Extraction function to fetch the movie director
def extract_director(obj):
    crew_list = ast.literal_eval(obj)
    director_list = [i['name'] for i in crew_list if i['job'] == 'Director']
    return ', '.join(director_list)

# %%
movies['crew'] = movies['crew'].apply(extract_director)

movies['crew']
# Out:
# 0                                James Cameron
# 1                               Gore Verbinski
# 2                                   Sam Mendes
# 3                            Christopher Nolan
# 4                               Andrew Stanton
#                          ...
# 4804                          Robert Rodriguez
# 4805                              Edward Burns
# 4806                               Scott Smith
# 4807                               Daniel Hsia
# 4808    Brian Herzlinger, Jon Gunn, Brett Winn
# Name: crew, Length: 4805, dtype: object

# %%
movies.head()
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4804  El Mariachi just wants to play his guitar and ...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Ever since the second grade when he first saw ...
#
#                                            genres  \
# 0     Action, Adventure, Fantasy, Science Fiction
# 1                      Adventure, Fantasy, Action
# 2                        Action, Adventure, Crime
# 3                  Action, Crime, Drama, Thriller
# 4              Action, Adventure, Science Fiction
# ...                                           ...
# 4804                      Action, Crime, Thriller
# 4805                              Comedy, Romance
# 4806             Comedy, Drama, Romance, TV Movie
# 4807
# 4808                                  Documentary
#
#                                                keywords  popularity  \
# 0     culture clash, future, space war, space colony...  150.437577
# 1     ocean, drug abuse, exotic island, east india t...  139.082615
# 2     spy, based on novel, secret agent, sequel, mi6...  107.376788
# 3     dc comics, crime fighter, terrorist, secret id...  112.312950
# 4     based on novel, mars, medallion, space travel,...   43.926995
# ...                                                 ...         ...
# 4804  united states–mexico barrier, legs, arms, pape...   14.269792
# 4805                                                       0.642552
# 4806  date, love at first sight, narration, investig...    1.444476
# 4807                                                       0.857008
# 4808            obsession, camcorder, crush, dream girl    1.929883
#
#                                                    cast  \
# 0     Sam Worthington (Jake Sully), Zoe Saldana (Ney...
# 1     Johnny Depp (Captain Jack Sparrow), Orlando Bl...
# 2     Daniel Craig (James Bond), Christoph Waltz (Bl...
# 3     Christian Bale (Bruce Wayne / Batman), Michael...
# 4     Taylor Kitsch (John Carter), Lynn Collins (Dej...
# ...                                                 ...
# 4804  Carlos Gallardo (El Mariachi), Jaime de Hoyos ...
# 4805  Edward Burns (Buzzy), Kerry Bishé (Linda), Mar...
# 4806  Eric Mabius (Oliver O’Toole), Kristin Booth (S...
# 4807  Daniel Henney (Sam), Eliza Coupe (Amanda), Bil...
# 4808  Drew Barrymore (Herself), Brian Herzlinger (Hi...
#
#                                         crew  \
# 0                              James Cameron
# 1                             Gore Verbinski
# 2                                 Sam Mendes
# 3                          Christopher Nolan
# 4                             Andrew Stanton
# ...                                      ...
# 4804                        Robert Rodriguez
# 4805                            Edward Burns
# 4806                             Scott Smith
# 4807                             Daniel Hsia
# 4808  Brian Herzlinger, Jon Gunn, Brett Winn
#
#                                    production_companies  runtime release_date
# 0     [{"name": "Ingenious Film Partners", "id": 289...    162.0   2009-12-10
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...    169.0   2007-05-19
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...    148.0   2015-10-26
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...    165.0   2012-07-16
# 4           [{"name": "Walt Disney Pictures", "id": 2}]    132.0   2012-03-07
# ...                                                 ...      ...          ...
# 4804           [{"name": "Columbia Pictures", "id": 5}]     81.0   1992-09-04
# 4805                                                 []     85.0   2011-12-26
# 4806  [{"name": "Front Street Pictures", "id": 3958}...    120.0   2013-10-13
# 4807                                                 []     98.0   2012-05-03
# 4808  [{"name": "rusty bear entertainment", "id": 87...     90.0   2005-08-05
#
# [4805 rows x 11 columns]

# %%
movies['release_year'] = pd.to_datetime(movies['release_date']).dt.year

#Drop the column release_date
movies.drop('release_date', axis=1, inplace=True)

# %%
movies['production_companies'].iloc[0]
# Out:
# '[{"name": "Ingenious Film Partners", "id": 289}, {"name": "Twentieth Century Fox Film Corporation", "id": 306}, {"name": "Dune Entertainment", "id": 444}, {"name": "Lightstorm Entertainment", "id": 574}]'

# %%
# Extraction function to get the first three company names
def extract_production_companies(obj, limit=3):
    companies_list = ast.literal_eval(obj)
    names_list = [company['name'] for company in companies_list[:limit]]
    return ', '.join(names_list)

# %%
movies['production_companies'] = movies['production_companies'].apply(extract_production_companies)

print(movies['production_companies'].iloc[0])
# Out:
# Ingenious Film Partners, Twentieth Century Fox Film Corporation, Dune Entertainment

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                         genres  \
# 0  Action, Adventure, Fantasy, Science Fiction
# 1                   Adventure, Fantasy, Action
# 2                     Action, Adventure, Crime
# 3               Action, Crime, Drama, Thriller
# 4           Action, Adventure, Science Fiction
#
#                                             keywords  popularity  \
# 0  culture clash, future, space war, space colony...  150.437577
# 1  ocean, drug abuse, exotic island, east india t...  139.082615
# 2  spy, based on novel, secret agent, sequel, mi6...  107.376788
# 3  dc comics, crime fighter, terrorist, secret id...  112.312950
# 4  based on novel, mars, medallion, space travel,...   43.926995
#
#                                                 cast               crew  \
# 0  Sam Worthington (Jake Sully), Zoe Saldana (Ney...      James Cameron
# 1  Johnny Depp (Captain Jack Sparrow), Orlando Bl...     Gore Verbinski
# 2  Daniel Craig (James Bond), Christoph Waltz (Bl...         Sam Mendes
# 3  Christian Bale (Bruce Wayne / Batman), Michael...  Christopher Nolan
# 4  Taylor Kitsch (John Carter), Lynn Collins (Dej...     Andrew Stanton
#
#                                 production_companies  runtime  release_year
# 0  Ingenious Film Partners, Twentieth Century Fox...    162.0          2009
# 1  Walt Disney Pictures, Jerry Bruckheimer Films,...    169.0          2007
# 2                     Columbia Pictures, Danjaq, B24    148.0          2015
# 3  Legendary Pictures, Warner Bros., DC Entertain...    165.0          2012
# 4                               Walt Disney Pictures    132.0          2012

# %%
import pickle

pickle.dump(movies,open('movies_dataset.pkl', 'wb'))

# %%
# Save as CSV
movies.to_csv('movies_dataset.csv', index=False)
